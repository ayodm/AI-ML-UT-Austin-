# %%
import pandas as pd
import seaborn as sns  # sns = reference to the west wing
import matplotlib.pyplot as plt # Seaborn is based on matplotlib
sns.set(color_codes=True) # Add clean background to graphs
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from PIL import Image

#import pandas_profiling
import pandas_profiling

# %%
data = pd.read_csv('CardioGoodFitness.csv')

# %% [markdown]
# ## Statistical summary

# %%
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
data.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
data.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Education'}>],
#        [<AxesSubplot:title={'center':'Usage'}>,
#         <AxesSubplot:title={'center':'Fitness'}>],
#        [<AxesSubplot:title={'center':'Income'}>,
#         <AxesSubplot:title={'center':'Miles'}>]], dtype=object)

# %%
sns.pairplot(data)

# %% [markdown]
# ## Univariate Analysis

# %%
plt.hist(data, bins=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9896439f863c> in <module>
# ----> 1 plt.hist(uni_analysis, bins=50)
#
# NameError: name 'uni_analysis' is not defined

# %%
sns.displot(data=data,kde=True);

# %%
sns.distplot(data, hist=False);

# %%
sns.violinplot(data);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a0d2abbddb42> in <module>
# ----> 1 sns.violinplot(data);
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2385 ):
#    2386
# -> 2387     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2388                              bw, cut, scale, scale_hue, gridsize,
#    2389                              width, inner, split, dodge, orient, linewidth,
#
# ...

# %%
plt.figure(figsize=(20,10))
plt.hist(data, color='g')
plt.axvline(data.mean(), color='y', linewidth=2)
plt.axvline(data.median(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(data.mode()[0], color='b', linestyle='dashed', linewidth=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-5771ab87f9cc> in <module>
#       1 plt.figure(figsize=(20,10))
#       2 plt.hist(data, color='g')
# ----> 3 plt.axvline(data.mean(), color='y', linewidth=2)
#       4 plt.axvline(data.median(), color='r', linestyle='dashed', linewidth=1)
#       5 plt.axvline(data.mode()[0], color='b', linestyle='dashed', linewidth=1)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in axvline(x, ymin, ymax, **kwargs)
#    2455 @_copy_docstring_and_deprecators(Axes.axvline)
#    2456 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2457     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#    2458
#    2459
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     911         self._process_unit_info(xdata=x, kwargs=kwargs)
# ...

# %% [markdown]
# ## Multi Variate Analysis

# %%
sns.distplot(data['Fitness'], hist_kws=dict(cumulative=True), kde_kws=dict(cumulative=True))

# %% [markdown]
# ## Insights & Recommendations
