# %% [markdown]
# ## Univariate and Multivariate Analysis - Melbourne Housing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings("ignore")
from PIL import Image

# %%
data = pd.read_csv("Melbourne_housing_FULL.csv")
data.head()
# Out:
#          Suburb           Address  Rooms Type Method        SellerG      Date  \
# 0    Abbotsford     68 Studley St      2    h     SS         Jellis  3/9/2016
# 1  Airport West     154 Halsey Rd      3    t     PI         Nelson  3/9/2016
# 2   Albert Park    105 Kerferd Rd      2    h      S  hockingstuart  3/9/2016
# 3   Albert Park  85 Richardson St      2    h      S        Thomson  3/9/2016
# 4    Alphington      30 Austin St      3    h     SN        McGrath  3/9/2016
#
#    Distance  Postcode  Bedroom  ...  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0      2.0  ...     126.0           inf        NaN
# 1      13.5    3042.0      3.0  ...     303.0           225     2016.0
# 2       3.3    3206.0      2.0  ...     120.0            82     1900.0
# 3       3.3    3206.0      2.0  ...     159.0           inf        NaN
# 4       6.4    3078.0      3.0  ...     174.0           122     2003.0
#
# ...

# %% [markdown]
# **For univariate analysis we will be using just the 'Distance' Column**

# %%
data = data['Distance']

# %%
data.head()
# Out:
# 0     2.5
# 1    13.5
# 2     3.3
# 3     3.3
# 4     6.4
# Name: Distance, dtype: float64

# %%
len(data)
# Out:
# 34857

# %%
# Check to see if any data in the Distance column is null
data.isnull().sum()
# Out:
# 1

# %%
data = data.dropna() # drops all the missing values in data

# %% [markdown]
# # Univariate Analysis
#
# Refers to the analysis of a single variable. THe main purpose of univariate analysis is to summarize and find patterns in the data. The key point is that htere is only one variable involved in the analysis.

# %%
# The code below plots a histogram using the matplotlib package. 
# the bins argument create class intervals. In this case we are creating 50 bins. 

plt.hist(data, bins=50)
# Out:
# (array([1.060e+02, 6.060e+02, 1.339e+03, 1.454e+03, 1.519e+03, 2.148e+03,
#         2.364e+03, 1.690e+03, 2.834e+03, 1.990e+03, 2.403e+03, 2.753e+03,
#         1.839e+03, 1.391e+03, 2.474e+03, 1.326e+03, 9.680e+02, 8.250e+02,
#         7.650e+02, 3.700e+02, 4.150e+02, 6.250e+02, 3.750e+02, 3.580e+02,
#         1.540e+02, 2.540e+02, 2.390e+02, 8.600e+01, 2.170e+02, 5.600e+01,
#         7.200e+01, 1.100e+01, 2.930e+02, 1.100e+01, 8.000e+00, 3.100e+01,
#         1.600e+02, 0.000e+00, 2.700e+01, 1.740e+02, 7.000e+00, 2.000e+00,
#         1.800e+01, 0.000e+00, 0.000e+00, 3.100e+01, 2.000e+00, 3.300e+01,
#         0.000e+00, 3.300e+01]),
#  array([ 0.   ,  0.962,  1.924,  2.886,  3.848,  4.81 ,  5.772,  6.734,
#          7.696,  8.658,  9.62 , 10.582, 11.544, 12.506, 13.468, 14.43 ,
#         15.392, 16.354, 17.316, 18.278, 19.24 , 20.202, 21.164, 22.126,
#         23.088, 24.05 , 25.012, 25.974, 26.936, 27.898, 28.86 , 29.822,
# ...

# %% [markdown]
# In the Above histogram, the first array is the frequency in each class and the second array contains the edges of the class intervals. These arrays can be assigned to a variable and used for further analysis.

# %%
sns.displot(data=data, kde=True)

# %%
sns.distplot(data, hist=False) # plots only the frequency
# Out:
# <AxesSubplot:xlabel='Distance', ylabel='Density'>

# %%
sns.violinplot(data) 
# gives us a focus on the # of houses, based on distance
# Out:
# <AxesSubplot:xlabel='Distance'>

# %% [markdown]
# Now let us have a closer look at the distribution by plotting a simple histogram with 10 bins

# %%
plt.figure(figsize=(20,10)) # makes the plot wider
plt.hist(data, color='g') # plots a simple histogram
plt.axvline(data.mean(), color='r', linewidth=2)
plt.axvline(data.median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(data.mode()[0], color='w', linestyle='dashed',linewidth=1)

# %% [markdown]
# * In the histogram above we can see that the second bin with class limit(4.81, 9.62) has the most number of observations.
# * A bulk of observations lie within the first four classes. the rest of the six classes contain fewer observations.
# * Since we are measuring distance. We can assume based on our visual observation that majority of the data points are less than 20kms
# * There are very few distances greater than 20 kms, past 30km even fewer
# * The mean is represented by the red line, median by the blue line, mode by the white line
# * The mean and the mode are very close to each other and the Median is less than them
#
# **Now we have an idea of how the data is distributed**

# %% [markdown]
# # Culmulative Distribution

# %%
sns.distplot(data, hist_kws=dict(cumulative=True), kde_kws=dict(cumulative=True))
# Out:
# <AxesSubplot:xlabel='Distance', ylabel='Density'>

# %% [markdown]
# # Multivariate Analysis
#
# Performed to understand the interactions between different fields in the dataset(or) finding the interactions between variables more than 2
#
# ex: Pairplot, 3D scatter plot
#
# # Scatter Plot
#
# Gives us an idea of the association between two variables

# %%
data1 = pd.read_csv("Melbourne_housing_FULL.csv")

# %%
data1.head()
# Out:
#          Suburb           Address  Rooms Type Method        SellerG      Date  \
# 0    Abbotsford     68 Studley St      2    h     SS         Jellis  3/9/2016
# 1  Airport West     154 Halsey Rd      3    t     PI         Nelson  3/9/2016
# 2   Albert Park    105 Kerferd Rd      2    h      S  hockingstuart  3/9/2016
# 3   Albert Park  85 Richardson St      2    h      S        Thomson  3/9/2016
# 4    Alphington      30 Austin St      3    h     SN        McGrath  3/9/2016
#
#    Distance  Postcode  Bedroom  ...  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0      2.0  ...     126.0           inf        NaN
# 1      13.5    3042.0      3.0  ...     303.0           225     2016.0
# 2       3.3    3206.0      2.0  ...     120.0            82     1900.0
# 3       3.3    3206.0      2.0  ...     159.0           inf        NaN
# 4       6.4    3078.0      3.0  ...     174.0           122     2003.0
#
# ...

# %%
data1 = data1.dropna()

# %%
sns.pairplot(data1)

# %% [markdown]
# **In the Above plot scatter diagrams are plotted for all the numerical columns in the dataset. A scatter plot is a visual representation of the degree of correlation between any two columns. The pair plot function in seaborn makes it very easy to generate joint scatter plots for all the columns in the data.**
#
# **A scatter plot can also be plotted for two individual columns:**

# %%
sns.scatterplot(data1['Price'],data1['Distance'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Distance'>

# %% [markdown]
# The scatter plot only offers visual information about the degree of correlation. In order to obtain more precise information we can us the inbuilt .corr() method in Pandas. This returns a table with all the correlations calculated for the numerical columns

# %%
data1.corr() # displays the correlation between every possible pair of attributes as a dataframe
# Out:
#                   Rooms  Distance  Postcode   Bedroom  Bathroom       Car  \
# Rooms          1.000000  0.276490  0.084078  0.964475  0.624138  0.401395
# Distance       0.276490  1.000000  0.489550  0.283365  0.122035  0.259328
# Postcode       0.084078  0.489550  1.000000  0.087130  0.111470  0.055520
# Bedroom        0.964475  0.283365  0.087130  1.000000  0.626560  0.405543
# Bathroom       0.624138  0.122035  0.111470  0.626560  1.000000  0.310975
# Car            0.401395  0.259328  0.055520  0.405543  0.310975  1.000000
# Landsize       0.101178  0.138568  0.069603  0.101054  0.075939  0.123466
# YearBuilt      0.006944  0.313238  0.089862  0.016320  0.192965  0.139322
# Latitude       0.019001 -0.055374 -0.195195  0.022983 -0.041642  0.015157
# Longtitude     0.082831  0.163922  0.358014  0.082491  0.109141  0.035530
# Propertycount -0.082604 -0.003173  0.032741 -0.081207 -0.058255 -0.031244
# Price          0.475096 -0.231222  0.045962  0.460906  0.463524  0.209439
#
# ...

# %%
sns.heatmap(data1.corr(), annot=True)
# Out:
# <AxesSubplot:>
