# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')


pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_rows', 200)

# %%
read_file = pd.read_excel("FIFA.xlsx")

read_file.to_csv ("Fifa.csv",
                 index=None,
                 header=True)
df = pd.DataFrame(pd.read_csv("Fifa.csv"))
df

fdata = df.copy()

# %%
fdata.head()
# Out:
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3         L. SuÃ¡rez   30
# 4           4           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# 4  https://cdn.sofifa.org/flags/21.png       92         92
#
#                   Club                                   Club Logo  Value  \
# 0       Real Madrid CF  https://cdn.sofifa.org/24/18/teams/243.png  95.5M
# 1         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png   105M
# 2  Paris Saint-Germain   https://cdn.sofifa.org/24/18/teams/73.png   123M
# 3         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png    97M
# 4     FC Bayern Munich   https://cdn.sofifa.org/24/18/teams/21.png    61M
#
#    Wage  Special Acceleration Aggression Agility Balance Ball control  \
# 0  565K     2228           89         63      89      63           93
# 1  565K     2154           92         48      90      95           95
# 2  280K     2100           94         56      96      82           95
# 3  510K     2291           88         78      86      60           91
# 4  230K     1493           58         29      52      35           48
#
#   Composure Crossing Curve Dribbling Finishing Free kick accuracy GK diving  \
# 0        95       85    81        91        94                 76         7
# 1        96       77    89        97        95                 90         6
# 2        92       75    81        96        89                 84         9
# 3        83       77    86        86        94                 84        27
# 4        70       15    14        30        13                 11        91
#
#   GK handling GK kicking GK positioning GK reflexes Heading accuracy  \
# 0          11         15             14          11               88
# 1          11         15             14           8               71
# 2           9         15             15          11               62
# 3          25         31             33          37               77
# 4          90         95             91          89               25
#
#   Interceptions Jumping Long passing Long shots Marking Penalties Positioning  \
# 0            29      95           77         92      22        85          95
# 1            22      68           87         88      13        74          93
# 2            36      61           75         77      21        81          90
# 3            41      69           64         86      30        85          92
# 4            30      78           59         16      10        47          12
#
#   Reactions Short passing Shot power Sliding tackle Sprint speed Stamina  \
# 0        96            83         94             23           91      92
# 1        95            88         85             26           87      73
# 2        88            81         80             33           90      78
# 3        93            83         87             38           77      89
# 4        85            55         25             11           61      44
#
#   Standing tackle Strength Vision Volleys   CAM    CB   CDM    CF    CM   LAM  \
# 0              31       80     85      88  89.0  53.0  62.0  91.0  82.0  89.0
# 1              28       59     90      85  92.0  45.0  59.0  92.0  84.0  92.0
# 2              24       53     80      83  88.0  46.0  59.0  88.0  79.0  88.0
# 3              45       80     84      88  87.0  58.0  65.0  88.0  80.0  87.0
# 4              10       83     70      11   NaN   NaN   NaN   NaN   NaN   NaN
#
#      LB   LCB   LCM   LDM    LF    LM    LS    LW   LWB Preferred Positions  \
# 0  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0              ST LW
# 1  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0                 RW
# 2  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0                 LW
# 3  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0                 ST
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN                 GK
#
#     RAM    RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  89.0  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  92.0  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  88.0  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  87.0  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
fdata.tail()
# Out:
#        Unnamed: 0           Name  Age  \
# 17976       17976      A. Kelsey   17
# 17977       17977  B. Richardson   47
# 17978       17978       J. Young   17
# 17979       17979   J. Lundstram   18
# 17980       17980      L. Sackey   18
#
#                                                  Photo Nationality  \
# 17976  https://cdn.sofifa.org/48/18/players/237463.png     England
# 17977   https://cdn.sofifa.org/48/18/players/11728.png     England
# 17978  https://cdn.sofifa.org/48/18/players/231381.png    Scotland
# 17979  https://cdn.sofifa.org/48/18/players/238813.png     England
# 17980  https://cdn.sofifa.org/48/18/players/238308.png       Ghana
#
#                                        Flag  Overall  Potential  \
# 17976   https://cdn.sofifa.org/flags/14.png       46         63
# 17977   https://cdn.sofifa.org/flags/14.png       46         46
# 17978   https://cdn.sofifa.org/flags/42.png       46         61
# 17979   https://cdn.sofifa.org/flags/14.png       46         64
# 17980  https://cdn.sofifa.org/flags/117.png       46         64
#
#                     Club                                    Club Logo Value  \
# 17976  Scunthorpe United  https://cdn.sofifa.org/24/18/teams/1949.png   50K
# 17977  Wycombe Wanderers  https://cdn.sofifa.org/24/18/teams/1933.png     0
# 17978       Swindon Town  https://cdn.sofifa.org/24/18/teams/1934.png   60K
# 17979    Crewe Alexandra   https://cdn.sofifa.org/24/18/teams/121.png   60K
# 17980  Scunthorpe United  https://cdn.sofifa.org/24/18/teams/1949.png   50K
#
#       Wage  Special Acceleration Aggression Agility Balance Ball control  \
# 17976   1K      755           24         16      38      26           12
# 17977   1K      832           25         44      35      44           22
# 17978   1K     1194           66         26      60      77           41
# 17979   1K     1302           57         46      58      74           43
# 17980   1K     1031           48         52      49      47           32
#
#       Composure Crossing Curve Dribbling Finishing Free kick accuracy  \
# 17976        23       14    13        12         5                 12
# 17977        44       11    12        11        11                 11
# 17978        50       28    32        37        47                 25
# 17979        45       34    30        41        32                 34
# 17980        33       19    17        23        20                 17
#
#       GK diving GK handling GK kicking GK positioning GK reflexes  \
# 17976        46          47         49             42          48
# 17977        39          50         39             50          37
# 17978        11          15         12             12          11
# 17979        10          13          7              8           9
# 17980        15           8         10             10           7
#
#       Heading accuracy Interceptions Jumping Long passing Long shots Marking  \
# 17976               10             9      31           21          7       9
# 17977               12            16      51           13         16      14
# 17978               47            16      73           30         51      18
# 17979               40            46      56           44         32      43
# 17980               48            38      60           24         17      38
#
#       Penalties Positioning Reactions Short passing Shot power Sliding tackle  \
# 17976        17           6        40            19         19             10
# 17977        22          13        51            12         13             13
# 17978        58          46        54            42         42             14
# 17979        43          37        49            49         43             47
# 17980        21          20        40            31         21             43
#
#       Sprint speed Stamina Standing tackle Strength Vision Volleys   CAM  \
# 17976           32      28              11       50     26       6   NaN
# 17977           25      32              12       47     17      12   NaN
# 17978           51      33              17       32     37      33  44.0
# 17979           58      49              48       46     51      25  45.0
# 17980           49      55              44       67     22      19  29.0
#
#          CB   CDM    CF    CM   LAM    LB   LCB   LCM   LDM    LF    LM    LS  \
# 17976   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 17977   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 17978  28.0  29.0  45.0  38.0  44.0  31.0  28.0  38.0  29.0  45.0  42.0  45.0
# 17979  46.0  47.0  43.0  45.0  45.0  47.0  46.0  45.0  47.0  43.0  45.0  41.0
# 17980  45.0  38.0  29.0  30.0  29.0  40.0  45.0  30.0  38.0  29.0  30.0  31.0
#
#          LW   LWB Preferred Positions   RAM    RB   RCB   RCM   RDM    RF  \
# 17976   NaN   NaN                 GK    NaN   NaN   NaN   NaN   NaN   NaN
# 17977   NaN   NaN                 GK    NaN   NaN   NaN   NaN   NaN   NaN
# 17978  44.0  32.0                 ST   44.0  31.0  28.0  38.0  29.0  45.0
# 17979  44.0  46.0                 CM   45.0  47.0  46.0  45.0  47.0  43.0
# 17980  29.0  38.0              ST CB   29.0  40.0  45.0  30.0  38.0  29.0
#
#          RM    RS    RW   RWB    ST
# 17976   NaN   NaN   NaN   NaN   NaN
# 17977   NaN   NaN   NaN   NaN   NaN
# 17978  42.0  45.0  44.0  32.0  45.0
# 17979  45.0  41.0  44.0  46.0  41.0
# 17980  30.0  31.0  29.0  38.0  31.0

# %%
fdata.shape
# Out:
# (17981, 74)

# %%
fdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 74 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           17981 non-null  int64
#  1   Name                 17981 non-null  object
#  2   Age                  17981 non-null  int64
#  3   Photo                17981 non-null  object
#  4   Nationality          17981 non-null  object
#  5   Flag                 17981 non-null  object
#  6   Overall              17981 non-null  int64
#  7   Potential            17981 non-null  int64
#  8   Club                 17733 non-null  object
#  9   Club Logo            17981 non-null  object
#  10  Value                17981 non-null  object
#  11  Wage                 17981 non-null  object
#  12  Special              17981 non-null  int64
#  13  Acceleration         17981 non-null  object
#  14  Aggression           17981 non-null  object
#  15  Agility              17981 non-null  object
#  16  Balance              17981 non-null  object
#  17  Ball control         17981 non-null  object
#  18  Composure            17981 non-null  object
#  19  Crossing             17981 non-null  object
#  20  Curve                17981 non-null  object
#  21  Dribbling            17981 non-null  object
#  22  Finishing            17981 non-null  object
#  23  Free kick accuracy   17981 non-null  object
#  24  GK diving            17981 non-null  object
#  25  GK handling          17981 non-null  object
#  26  GK kicking           17981 non-null  object
#  27  GK positioning       17981 non-null  object
#  28  GK reflexes          17981 non-null  object
#  29  Heading accuracy     17981 non-null  object
#  30  Interceptions        17981 non-null  object
#  31  Jumping              17981 non-null  object
#  32  Long passing         17981 non-null  object
#  33  Long shots           17981 non-null  object
#  34  Marking              17981 non-null  object
#  35  Penalties            17981 non-null  object
#  36  Positioning          17981 non-null  object
#  37  Reactions            17981 non-null  object
#  38  Short passing        17981 non-null  object
#  39  Shot power           17981 non-null  object
#  40  Sliding tackle       17981 non-null  object
#  41  Sprint speed         17981 non-null  object
#  42  Stamina              17981 non-null  object
#  43  Standing tackle      17981 non-null  object
#  44  Strength             17981 non-null  object
#  45  Vision               17981 non-null  object
#  46  Volleys              17981 non-null  object
#  47  CAM                  15952 non-null  float64
#  48  CB                   15952 non-null  float64
#  49  CDM                  15952 non-null  float64
#  50  CF                   15952 non-null  float64
#  51  CM                   15952 non-null  float64
#  52  LAM                  15952 non-null  float64
#  53  LB                   15952 non-null  float64
#  54  LCB                  15952 non-null  float64
#  55  LCM                  15952 non-null  float64
#  56  LDM                  15952 non-null  float64
#  57  LF                   15952 non-null  float64
#  58  LM                   15952 non-null  float64
#  59  LS                   15952 non-null  float64
#  60  LW                   15952 non-null  float64
#  61  LWB                  15952 non-null  float64
#  62  Preferred Positions  17981 non-null  object
#  63  RAM                  15952 non-null  float64
#  64  RB                   15952 non-null  float64
#  65  RCB                  15952 non-null  float64
#  66  RCM                  15952 non-null  float64
#  67  RDM                  15952 non-null  float64
#  68  RF                   15952 non-null  float64
#  69  RM                   15952 non-null  float64
#  70  RS                   15952 non-null  float64
#  71  RW                   15952 non-null  float64
#  72  RWB                  15952 non-null  float64
#  73  ST                   15952 non-null  float64
# dtypes: float64(26), int64(5), object(43)
# memory usage: 10.2+ MB

# %%
fdata.drop(['Photo','Flag','Club Logo'], axis=1, inplace=True)

# %%
fdata.describe(include='all')
# Out:
#           Unnamed: 0         Name           Age Nationality       Overall  \
# count   17981.000000        17981  17981.000000       17981  17981.000000
# unique           NaN        16975           NaN         165           NaN
# top              NaN  J. Valencia           NaN     England           NaN
# freq             NaN            7           NaN        1630           NaN
# mean     8990.000000          NaN     25.144541         NaN     66.247984
# std      5190.811931          NaN      4.614272         NaN      6.987965
# min         0.000000          NaN     16.000000         NaN     46.000000
# 25%      4495.000000          NaN     21.000000         NaN     62.000000
# 50%      8990.000000          NaN     25.000000         NaN     66.000000
# 75%     13485.000000          NaN     28.000000         NaN     71.000000
# max     17980.000000          NaN     47.000000         NaN     94.000000
#
#            Potential           Club  Value   Wage       Special Acceleration  \
# count   17981.000000          17733  17981  17981  17981.000000        17981
# unique           NaN            647    207    142           NaN          161
# top              NaN  Villarreal CF   1.1M     1K           NaN           68
# freq             NaN             35    387   4201           NaN          706
# mean       71.190813            NaN    NaN    NaN   1594.095100          NaN
# std         6.102199            NaN    NaN    NaN    272.151435          NaN
# min        46.000000            NaN    NaN    NaN    728.000000          NaN
# 25%        67.000000            NaN    NaN    NaN   1449.000000          NaN
# 50%        71.000000            NaN    NaN    NaN   1633.000000          NaN
# 75%        75.000000            NaN    NaN    NaN   1786.000000          NaN
# max        94.000000            NaN    NaN    NaN   2291.000000          NaN
#
#        Aggression Agility Balance Ball control Composure Crossing  Curve  \
# count       17981   17981   17981        17981     17981    17981  17981
# unique        151     146     135          184       161      176    153
# top            70      72      68           64        60       62     45
# freq          495     605     609          739       708      527    395
# mean          NaN     NaN     NaN          NaN       NaN      NaN    NaN
# std           NaN     NaN     NaN          NaN       NaN      NaN    NaN
# min           NaN     NaN     NaN          NaN       NaN      NaN    NaN
# 25%           NaN     NaN     NaN          NaN       NaN      NaN    NaN
# 50%           NaN     NaN     NaN          NaN       NaN      NaN    NaN
# 75%           NaN     NaN     NaN          NaN       NaN      NaN    NaN
# max           NaN     NaN     NaN          NaN       NaN      NaN    NaN
#
#        Dribbling Finishing Free kick accuracy GK diving GK handling  \
# count      17981     17981              17981     17981       17981
# unique       194       187                198       100          97
# top           65        60                 42         8          10
# freq         694       428                423      1645        1643
# mean         NaN       NaN                NaN       NaN         NaN
# std          NaN       NaN                NaN       NaN         NaN
# min          NaN       NaN                NaN       NaN         NaN
# 25%          NaN       NaN                NaN       NaN         NaN
# 50%          NaN       NaN                NaN       NaN         NaN
# 75%          NaN       NaN                NaN       NaN         NaN
# max          NaN       NaN                NaN       NaN         NaN
#
#        GK kicking GK positioning GK reflexes Heading accuracy Interceptions  \
# count       17981          17981       17981            17981         17981
# unique        103             99         102              158           174
# top            12              8           9               58            65
# freq         1606           1622        1630              612           477
# mean          NaN            NaN         NaN              NaN           NaN
# std           NaN            NaN         NaN              NaN           NaN
# min           NaN            NaN         NaN              NaN           NaN
# 25%           NaN            NaN         NaN              NaN           NaN
# 50%           NaN            NaN         NaN              NaN           NaN
# 75%           NaN            NaN         NaN              NaN           NaN
# max           NaN            NaN         NaN              NaN           NaN
#
#        Jumping Long passing Long shots Marking Penalties Positioning  \
# count    17981        17981      17981   17981     17981       17981
# unique     140          188        156     183       181         171
# top         72           58         59      65        55          62
# freq       709          605        452     467       463         514
# mean       NaN          NaN        NaN     NaN       NaN         NaN
# std        NaN          NaN        NaN     NaN       NaN         NaN
# min        NaN          NaN        NaN     NaN       NaN         NaN
# 25%        NaN          NaN        NaN     NaN       NaN         NaN
# 50%        NaN          NaN        NaN     NaN       NaN         NaN
# 75%        NaN          NaN        NaN     NaN       NaN         NaN
# max        NaN          NaN        NaN     NaN       NaN         NaN
#
#        Reactions Short passing Shot power Sliding tackle Sprint speed Stamina  \
# count      17981         17981      17981          17981        17981   17981
# unique       158           209        153            169          194     180
# top           64            64         68             62           68      72
# freq         849           807        556            504          759     624
# mean         NaN           NaN        NaN            NaN          NaN     NaN
# std          NaN           NaN        NaN            NaN          NaN     NaN
# min          NaN           NaN        NaN            NaN          NaN     NaN
# 25%          NaN           NaN        NaN            NaN          NaN     NaN
# 50%          NaN           NaN        NaN            NaN          NaN     NaN
# 75%          NaN           NaN        NaN            NaN          NaN     NaN
# max          NaN           NaN        NaN            NaN          NaN     NaN
#
#        Standing tackle Strength Vision Volleys           CAM            CB  \
# count            17981    17981  17981   17981  15952.000000  15952.000000
# unique             187      168    173     125           NaN           NaN
# top                 66       72     58      48           NaN           NaN
# freq               559      627    537     413           NaN           NaN
# mean               NaN      NaN    NaN     NaN     59.251755     55.550464
# std                NaN      NaN    NaN     NaN      9.880164     12.192579
# min                NaN      NaN    NaN     NaN     27.000000     25.000000
# 25%                NaN      NaN    NaN     NaN     53.000000     45.000000
# 50%                NaN      NaN    NaN     NaN     60.000000     57.000000
# 75%                NaN      NaN    NaN     NaN     66.000000     65.000000
# max                NaN      NaN    NaN     NaN     92.000000     87.000000
#
#                  CDM            CF            CM           LAM            LB  \
# count   15952.000000  15952.000000  15952.000000  15952.000000  15952.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       56.865283     59.030028     58.506833     59.251755     56.979689
# std        10.310178      9.926988      8.888040      9.880164      9.791627
# min        26.000000     27.000000     30.000000     27.000000     30.000000
# 25%        49.000000     53.000000     53.000000     53.000000     50.000000
# 50%        58.000000     60.000000     59.000000     60.000000     58.000000
# 75%        65.000000     66.000000     65.000000     66.000000     64.000000
# max        85.000000     92.000000     87.000000     92.000000     84.000000
#
#                  LCB           LCM           LDM            LF            LM  \
# count   15952.000000  15952.000000  15952.000000  15952.000000  15952.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       55.550464     58.506833     56.865283     59.030028     60.057736
# std        12.192579      8.888040     10.310178      9.926988      9.349180
# min        25.000000     30.000000     26.000000     27.000000     28.000000
# 25%        45.000000     53.000000     49.000000     53.000000     54.000000
# 50%        57.000000     59.000000     58.000000     60.000000     61.000000
# 75%        65.000000     65.000000     65.000000     66.000000     67.000000
# max        87.000000     87.000000     85.000000     92.000000     90.000000
#
#                   LS            LW           LWB Preferred Positions  \
# count   15952.000000  15952.000000  15952.000000               17981
# unique           NaN           NaN           NaN                 802
# top              NaN           NaN           NaN                 CB
# freq             NaN           NaN           NaN                2216
# mean       58.204050     59.359265     57.698721                 NaN
# std         9.181392      9.978084      9.142825                 NaN
# min        31.000000     26.000000     31.000000                 NaN
# 25%        52.000000     53.000000     51.000000                 NaN
# 50%        59.000000     60.000000     58.000000                 NaN
# 75%        65.000000     66.000000     64.000000                 NaN
# max        92.000000     91.000000     84.000000                 NaN
#
#                  RAM            RB           RCB           RCM           RDM  \
# count   15952.000000  15952.000000  15952.000000  15952.000000  15952.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       59.251755     56.979689     55.550464     58.506833     56.865283
# std         9.880164      9.791627     12.192579      8.888040     10.310178
# min        27.000000     30.000000     25.000000     30.000000     26.000000
# 25%        53.000000     50.000000     45.000000     53.000000     49.000000
# 50%        60.000000     58.000000     57.000000     59.000000     58.000000
# 75%        66.000000     64.000000     65.000000     65.000000     65.000000
# max        92.000000     84.000000     87.000000     87.000000     85.000000
#
#                   RF            RM            RS            RW           RWB  \
# count   15952.000000  15952.000000  15952.000000  15952.000000  15952.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       59.030028     60.057736     58.204050     59.359265     57.698721
# std         9.926988      9.349180      9.181392      9.978084      9.142825
# min        27.000000     28.000000     31.000000     26.000000     31.000000
# 25%        53.000000     54.000000     52.000000     53.000000     51.000000
# 50%        60.000000     61.000000     59.000000     60.000000     58.000000
# 75%        66.000000     67.000000     65.000000     66.000000     64.000000
# max        92.000000     90.000000     92.000000     91.000000     84.000000
#
#                   ST
# count   15952.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       58.204050
# std         9.181392
# min        31.000000
# 25%        52.000000
# 50%        59.000000
# 75%        65.000000
# max        92.000000

# %%
fdata.isnull().sum()
# Out:
# Unnamed: 0                0
# Name                      0
# Age                       0
# Nationality               0
# Overall                   0
# Potential                 0
# Club                    248
# Value                     0
# Wage                      0
# Special                   0
# Acceleration              0
# Aggression                0
# Agility                   0
# Balance                   0
# Ball control              0
# Composure                 0
# Crossing                  0
# Curve                     0
# Dribbling                 0
# Finishing                 0
# Free kick accuracy        0
# GK diving                 0
# GK handling               0
# GK kicking                0
# GK positioning            0
# GK reflexes               0
# Heading accuracy          0
# Interceptions             0
# Jumping                   0
# Long passing              0
# Long shots                0
# Marking                   0
# Penalties                 0
# Positioning               0
# Reactions                 0
# Short passing             0
# Shot power                0
# Sliding tackle            0
# Sprint speed              0
# Stamina                   0
# Standing tackle           0
# Strength                  0
# Vision                    0
# Volleys                   0
# CAM                    2029
# CB                     2029
# CDM                    2029
# CF                     2029
# CM                     2029
# LAM                    2029
# LB                     2029
# LCB                    2029
# LCM                    2029
# LDM                    2029
# LF                     2029
# LM                     2029
# LS                     2029
# LW                     2029
# LWB                    2029
# Preferred Positions       0
# RAM                    2029
# RB                     2029
# RCB                    2029
# RCM                    2029
# RDM                    2029
# RF                     2029
# RM                     2029
# RS                     2029
# RW                     2029
# RWB                    2029
# ST                     2029
# dtype: int64

# %%
#def missing_check(df):
#    total = df.isnull().sum().sort_values(ascending=False)   # total number of null values
#    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)  # percentage of values that are null
#    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])  # putting the above two together
#    return missing_data # return the dataframe
#missing_check(fdata)

# %% [markdown]
# ### Ranked Order List

# %%
# Top 10 countries with most players
TopTen = fdata['Nationality']
TopTen.value_counts(ascending=False).head(10)
# Out:
# England        1630
# Germany        1140
# Spain          1019
# France          978
# Argentina       965
# Brazil          812
# Italy           799
# Colombia        592
# Japan           469
# Netherlands     429
# Name: Nationality, dtype: int64

# %%
# 5 Countries producing the most footballers and the continent each country is located in'
TopFive = fdata['Nationality']
TopFive.value_counts(ascending=False).head(5)

# We have the Top 5 Countries producing the most footballers however we don't have a continent column that tells us 
# which continent each country is located in, so I have created a new df column called continent, which I will be 
# Appending to fdata
# Out:
# England      1630
# Germany      1140
# Spain        1019
# France        978
# Argentina     965
# Name: Nationality, dtype: int64

# %%
fdata['Nationality'].replace("SÃ£o TomÃ© & PrÃ\xadncipe","Saint Thomas and Prince", inplace=True)

# %%
#countrylist = {'Country Name': fdata['Nationality'].unique()}
#cl = pd.DataFrame(countrylist)
#print(cl)

# %%
# Create column Continent in fdata so that we can identify which continents each player originates from
#import country_converter as coco
#converter = coco.CountryConverter()

# %% [markdown]
# ## Interpret a particular age

# %%
Players_D = fdata[["Age", "Overall", "Potential"]].copy()
sortedbyage = Players_D.sort_values(by="Age")
sortedbyage.info()

Players_D.to_csv("Players_D.csv", index=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17981 entries, 15837 to 17977
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        17981 non-null  int64
#  1   Overall    17981 non-null  int64
#  2   Potential  17981 non-null  int64
# dtypes: int64(3)
# memory usage: 561.9 KB

# %%
sortedbyage.describe(include="all")
# Out:
#                 Age       Overall     Potential
# count  17981.000000  17981.000000  17981.000000
# mean      25.144541     66.247984     71.190813
# std        4.614272      6.987965      6.102199
# min       16.000000     46.000000     46.000000
# 25%       21.000000     62.000000     67.000000
# 50%       25.000000     66.000000     71.000000
# 75%       28.000000     71.000000     75.000000
# max       47.000000     94.000000     94.000000

# %%
groupedbyage = Players_D.groupby('Age')
print(groupedbyage)

groupedbyage.describe()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fc71b16dac0>
#     Overall                                                      Potential  \
#       count       mean       std   min    25%   50%    75%   max     count
# Age
# 16     13.0  57.846154  4.017590  51.0  54.00  58.0  59.00  65.0      13.0
# 17    258.0  56.089147  5.097092  46.0  52.00  55.5  60.00  76.0     258.0
# 18    672.0  57.287202  5.591879  46.0  53.00  57.0  61.00  83.0     672.0
# 19   1069.0  59.430309  5.699239  47.0  56.00  59.0  63.00  80.0    1069.0
# 20   1245.0  61.559839  6.040644  48.0  57.00  61.0  65.00  83.0    1245.0
# 21   1286.0  63.395023  6.149457  48.0  59.00  63.0  67.00  84.0    1286.0
# 22   1324.0  64.762085  6.308045  48.0  60.00  64.0  69.00  84.0    1324.0
# 23   1394.0  66.117647  6.116875  50.0  62.00  66.0  70.00  88.0    1394.0
# 24   1334.0  67.182909  6.083525  50.0  63.00  67.0  71.00  88.0    1334.0
# 25   1522.0  68.008541  5.918629  49.0  64.00  68.0  72.00  92.0    1522.0
# 26   1202.0  68.643927  6.000666  50.0  65.00  68.0  72.00  90.0    1202.0
# 27   1152.0  68.943576  5.882526  51.0  65.00  69.0  73.00  90.0    1152.0
# 28   1051.0  69.058040  6.000275  46.0  65.00  69.0  73.00  91.0    1051.0
# 29   1121.0  69.722569  5.336257  52.0  66.00  70.0  73.00  90.0    1121.0
# 30    804.0  69.847015  6.019911  49.0  66.00  69.0  73.00  93.0     804.0
# 31    671.0  69.767511  5.692851  52.0  66.00  69.0  73.00  92.0     671.0
# 32    506.0  69.468379  5.666297  48.0  66.00  69.0  73.00  94.0     506.0
# 33    617.0  69.709887  5.245757  51.0  67.00  70.0  73.00  88.0     617.0
# 34    272.0  68.911765  5.741634  49.0  65.00  69.0  72.00  86.0     272.0
# 35    191.0  69.151832  5.532962  54.0  65.50  69.0  72.00  88.0     191.0
# 36    136.0  69.080882  6.279957  52.0  65.00  69.0  73.00  85.0     136.0
# 37     69.0  68.536232  5.481465  52.0  65.00  70.0  72.00  80.0      69.0
# 38     36.0  68.666667  6.061589  52.0  66.00  70.0  72.00  79.0      36.0
# 39     20.0  67.900000  7.880021  52.0  65.75  67.5  71.00  89.0      20.0
# 40      8.0  67.625000  7.190023  56.0  62.50  69.0  73.25  76.0       8.0
# 41      3.0  64.333333  6.429101  57.0  62.00  67.0  68.00  69.0       3.0
# 43      2.0  55.000000  0.000000  55.0  55.00  55.0  55.00  55.0       2.0
# 44      2.0  70.500000  0.707107  70.0  70.25  70.5  70.75  71.0       2.0
# 47      1.0  46.000000       NaN  46.0  46.00  46.0  46.00  46.0       1.0
#
#
#           mean       std   min    25%   50%    75%   max
# Age
# 16   76.538462  6.728241  66.0  70.00  78.0  80.00  90.0
# 17   73.492248  6.012466  59.0  69.00  74.0  78.00  89.0
# 18   72.654762  6.142848  56.0  68.00  72.0  77.00  94.0
# 19   72.815716  5.768854  56.0  69.00  73.0  77.00  89.0
# 20   72.717269  6.059358  57.0  69.00  72.0  77.00  92.0
# 21   72.790047  6.083422  53.0  69.00  73.0  77.00  92.0
# 22   72.542296  6.253684  55.0  68.00  72.0  77.00  91.0
# 23   72.489957  6.030335  54.0  69.00  72.0  76.00  93.0
# 24   72.090705  6.006874  53.0  68.00  72.0  76.00  93.0
# 25   70.836399  5.857628  52.0  67.00  70.0  74.00  94.0
# 26   70.574875  6.123606  50.0  66.00  70.0  74.00  92.0
# 27   69.697917  5.960693  51.0  66.00  69.0  74.00  90.0
# 28   69.304472  6.020645  46.0  65.00  69.0  73.00  91.0
# 29   69.763604  5.329697  52.0  66.00  70.0  73.00  90.0
# 30   69.853234  6.021618  49.0  66.00  69.0  73.00  93.0
# 31   69.767511  5.692851  52.0  66.00  69.0  73.00  92.0
# 32   69.468379  5.666297  48.0  66.00  69.0  73.00  94.0
# 33   69.709887  5.245757  51.0  67.00  70.0  73.00  88.0
# 34   68.911765  5.741634  49.0  65.00  69.0  72.00  86.0
# 35   69.151832  5.532962  54.0  65.50  69.0  72.00  88.0
# 36   69.080882  6.279957  52.0  65.00  69.0  73.00  85.0
# 37   68.536232  5.481465  52.0  65.00  70.0  72.00  80.0
# 38   68.666667  6.061589  52.0  66.00  70.0  72.00  79.0
# 39   67.900000  7.880021  52.0  65.75  67.5  71.00  89.0
# 40   67.625000  7.190023  56.0  62.50  69.0  73.25  76.0
# 41   64.333333  6.429101  57.0  62.00  67.0  68.00  69.0
# 43   55.000000  0.000000  55.0  55.00  55.0  55.00  55.0
# 44   70.500000  0.707107  70.0  70.25  70.5  70.75  71.0
# 47   46.000000       NaN  46.0  46.00  46.0  46.00  46.0

# %%
sns.distplot(Players_D['Age'], kde=False, rug=True);

# %%
sns.jointplot(Players_D['Age'],Players_D['Overall']);
sns.jointplot(data = Players_D, y='Age',x='Overall', kind='reg');

g = sns.JointGrid(data=Players_D, x='Age', y='Overall')
g.plot(sns.regplot, sns.boxplot)

# %%
sns.jointplot(Players_D['Age'],Players_D['Overall'], kind="hist");

# %%
# sns.jointplot(Players_D['Age'],Players_D['Overall'], kind="kde");

# %%
sns.pairplot(Players_D[['Age','Overall']]);

# %% [markdown]
# From the Graphs we've used to visualize the distribution of Age compared to Overall ratings above, one could infer that most players stop improving once they reach 25 years old.

# %% [markdown]
# ## Analysis of offensive players

# %%
OPlayers = fdata[['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
    'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM',
    'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
    'LCB', 'CB', 'RCB', 'RB', 'Wage']].copy()


def position_to_num(pos_val):
    """For each value, take the number before the '+'
    unless it is not a string value. This will only happen
    for NaNs so in that case we just return NaN.
    """
    
    if isinstance(pos_val,str):
        return float(pos_val.split('+')[0])
    else: 
        return np.nan
    
position_cols = [
    'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
    'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM',
    'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
    'LCB', 'CB', 'RCB', 'RB'
]

for colname in position_cols:
    OPlayers[colname] = df[colname].apply(position_to_num)
    
    
# Replacing Position Names 
    
off_pos_to_cols = {
    'Striker': ['ST', 'CF','LS','RF','LF', 'RS'], 
    'Right-Winger': ['RW'],
    'Left-Winger': ['LW']
#    'Left-Midfield':['LM', 'LAM'],
#    'Right-Midfield':['RM', 'RAM'],
#    'Right-DefMid':['RDM'],
#    'Left-DefMid':['LDM'],
#    'Center-Mid':['CM','CAM'],
#    'Center-DefMid':['CDM'],
#    'Right-Defense':['RB','RCB'],
#    'Center-Def':['CB'], 
#    'Left-Defense':['LB','LCB']    
}

for pos_type, colvec in off_pos.cols.items():
    OPlayers[pos_type +'_rate']= rount(df[colvec].mean(axis=1))
    
    
OPlayers.drop(position_cols, axis=1, inplace=True)

print(OPlayers.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d391859b4ee2> in <module>
#      44 }
#      45
# ---> 46 for pos_type, colvec in off_pos.cols.items():
#      47     OPlayers[pos_type +'_rate']= rount(df[colvec].mean(axis=1))
#      48
#
# NameError: name 'off_pos' is not defined

# %%
#OPlayers = fdata[["Wage", "", "Potential"]].copy()
#sortedbyage = Players_D.sort_values(by="Age")
#sortedbyage.info()

#Players_D.to_csv("Players_D.csv", index=True)

# %% [markdown]
# ## Best players for 2018

# %%
rw = fdata[["Name","Overall", "Potential", "Preferred Positions"]].nlargest(20, "Overall")
 
rw1 = fdata.groupby("Preferred Positions")

print(rw)

# %%
rw1 = fdata.groupby("Preferred Positions")
rw1.first()

# %% [markdown]
# ## Analysis of different players and clubs

# %%
ClubRanking = fdata[['Club','Nationality','Name']].groupby(['Club','Nationality'])['Nationality'].count().nlargest(5, )
print(ClubRanking)

# %% [markdown]
# ## Formation of best and insights
